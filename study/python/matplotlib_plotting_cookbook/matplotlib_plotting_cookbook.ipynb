# %% [markdown]
# ## Chapter 01 첫걸음

# %%
import matplotlib.pyplot as plt

X = list(range(100))
Y = [value ** 2 for value in X]

plt.plot(X, Y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(0, 2 * np.pi, 100)
Y = np.sin(X)

plt.plot(X, Y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-3, 2, 200)
Y = X ** 2 - 2 * X + 1.

plt.plot(X, Y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(0, 2 * np.pi, 100)
Ya = np.sin(X)
Yb = np.cos(X)

plt.plot(X, Ya)
plt.plot(X, Yb)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_slope(X, Y):
    Xs = X[1:] - X[:-1]
    Ys = Y[1:] - Y[:-1]
    
    plt.plot(X[1:], Ys / Xs)

X = np.linspace(-3, 3, 100)
Y = np.exp(-X**2)

plt.plot(X, Y)
plot_slope(X, Y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('my_data.txt')

for column in data.T:
    plt.plot(data[:, 0], column)
    
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

data = np.random.rand(1024, 2)

plt.scatter(data[:, 0], data[:, 1])
plt.show()

# %%
from matplotlib import pyplot as plt

data = [5., 25., 50., 20.]

plt.bar(range(len(data)), data)
plt.show()

# %%
from matplotlib import pyplot as plt

data = [5., 25., 50., 20.]

plt.barh(range(len(data)), data)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

data = [[5., 25., 50., 20.], [4., 23., 51., 17.], [6., 22., 52., 19.]]

color_list = ['b', 'g', 'r']
gap = .8 / len(data)

for i, row in enumerate(data):
    X = np.arange(len(row))
    plt.bar(X + i * gap, row, width = gap, color = color_list[i % len(color_list)])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.array([[5., 30., 45., 22.],[5., 25., 50., 20.],[1., 2., 1., 1.]])

color_list = ['b','g','r']

X = np.arange(data.shape[1])

for i in range(data.shape[0]):
    plt.bar(X, data[i], bottom = np.sum(data[:i], axis = 0), 
            color = color_list[i % len(color_list)])
    
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

women_pop = np.array([5., 30., 45., 22.])
men_pop = np.array([5., 25., 50., 20.])
X = np.arange(4)

plt.barh(X, women_pop, color = 'r')
plt.barh(X, -men_pop, color='b')

plt.show()

# %%
from matplotlib import pyplot as plt

data = [5, 25, 50, 20]

plt.pie(data)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.random.randn(1000)

plt.hist(X, bins = 20)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

data = np.random.randn(100, 5)

plt.boxplot(data)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import tri as ti

data = np.random.rand(100, 2)

triangles = ti.Triangulation(data[:, 0], data[:, 1])

plt.triplot(triangles)
plt.show()

# %% [markdown]
# ## Chapter 02 컬러와 스타일 사용자 정의

# %%
import numpy as np
from matplotlib import pyplot as plt

def pdf(X, mu, sigma):
    a = 1. / (sigma * np.sqrt(2. * np.pi))
    b = -1. / (2. * sigma ** 2)
    
    return a * np.exp(b * (X - mu) ** 2)

X = np.linspace(-6, 6, 1000)

for i in range(5):
    samples = np.random.standard_normal(50)
    mu, sigma = np.mean(samples), np.std(samples)
    plt.plot(X, pdf(X, mu, sigma), color = '.75')

plt.plot(X, pdf(X, 0., 1.), color='k')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

A = np.random.standard_normal((100, 2))
A += np.array((-1, -1))

B = np.random.standard_normal((100, 2))
B += np.array((1, 1))

plt.scatter(A[:, 0], A[:, 1], color='1.0', edgecolor='0.0')
plt.scatter(B[:, 0], B[:, 1], color='.75', edgecolor='0.0')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

label_set = (
    b'Iris-setosa',
    b'Iris-versicolor',
    b'Iris-virginica',
)

def read_label(label):
    return label_set.index(label)

data = np.loadtxt('iris.data', delimiter = ',', converters = { 4: read_label})
color_set = ('.00','.50','.75')
color_list = [color_set[int(lable)] for lable in data[:, 4]]

plt.scatter(data[:,0], data[:,1], color = color_list, edgecolor='0.0')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

women_pop = np.array([5., 30., 45., 22.])
men_pop = np.array([5., 25., 50., 20.])

X = np.arange(4)
plt.barh(X, women_pop, color='.25')
plt.barh(X, -men_pop, color='.75')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

values = np.random.randint(1, 100, size=50)

color_set = ('.00','.25','.50','.75')
color_list = [color_set[(len(color_set) * val) // 100] for val in values]

plt.bar(np.arange(len(values)), values, color=color_list)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

values = np.random.rand(8)
color_set = ('.00','.25','.50','.75')

plt.pie(values, colors = color_set)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

values = np.random.randn(100)

b = plt.boxplot(values)

for name, line_list in b.items():
    for line in line_list:
        line.set_color('k')

plt.show()

# %%
import numpy as np
from matplotlib import cm as cm
from matplotlib import pyplot as plt

N = 256
angle = np.linspace(0, 8 * 2 * np.pi, N)
radius = np.linspace(.5, 1., N)


X = radius * np.cos(angle)
Y = radius * np.sin(angle)

plt.scatter(X, Y, c = angle, cmap = cm.hsv)
plt.show()

# %%
import numpy as np
from matplotlib import cm as cm
from matplotlib import colors as col
from matplotlib import pyplot as plt

values = np.random.randint(1, 100, size=50)
cmap = cm.ScalarMappable(col.Normalize(0, 99), cm.binary)

plt.bar(np.arange(len(values)), values, color = cmap.to_rgba(values))
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

def pdf(X, mu, sigma):
    a = 1. / (sigma * np.sqrt(2. * np.pi))
    b = -1 / (2. * sigma ** 2)
    
    return a * np.exp(b * (X - mu) ** 2)

X = np.linspace(-6, 6, 1024)

plt.plot(X, pdf(X, 0., 1.), color = 'k', linestyle = 'solid')
plt.plot(X, pdf(X, 0., .5), color = 'k', linestyle = 'dashed')
plt.plot(X, pdf(X, 0., .25), color = 'k', linestyle = 'dashdot')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

N = 8
A = np.random.random(N)
B = np.random.random(N)
X = np.arange(N)

plt.bar(X, A, color='.75')
plt.bar(X, A + B, bottom = A, color = 'r', linestyle = 'dashed')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

def pdf(X, mu, sigma):
    a = 1. / (sigma * np.sqrt(2. * np.pi))
    b = -1 / (2. * sigma ** 2)
    
    return a * np.exp(b * (X - mu) ** 2)

X = np.linspace(-6, 6, 1024)
for i in range(64):
    samples = np.random.standard_normal(50)
    mu, sigma = np.mean(samples), np.std(samples)
    plt.plot(X, pdf(X, mu, sigma), color = '.75', linewidth = .5)

plt.plot(X, pdf(X, 0., 1.), color='r', linewidth= 3.)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

N = 8
A = np.random.random(N)
B = np.random.random(N)
X = np.arange(N)

plt.bar(X, A, color='w', hatch='x')
plt.bar(X, A + B, bottom = A, color = 'w', hatch = '/')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

A = np.random.standard_normal((100, 2))
A += np.array((-1, -1))

B = np.random.standard_normal((100, 2))
B += np.array((1, 1))

plt.scatter(A[:, 0], A[:, 1], color='k', marker = 'x')
plt.scatter(B[:, 0], B[:, 1], color='k', marker = '^')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

lable_list = (
    b'Iris-setosa',
    b'Iris-versicolor',
    b'Iris-virginica',
)

def read_label(label):
    return lable_list.index(label)

data = np.loadtxt('iris.data', delimiter = ',', converters = {4: read_label})
marker_set = ('^','*','.')

for i, marker  in enumerate(marker_set):
    data_subset = np.asarray([x for x in data if x[4] == i])
    plt.scatter(data_subset[:, 0], data_subset[:, 1], color='k', marker = marker)

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-6, 6, 1024)
Y1 = np.sinc(X)
Y2 = np.sinc(X) + 1

plt.plot(X, Y1, marker = 'o', color='.75')
plt.plot(X, Y2, marker = 'o', color='k', markevery = 32)

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

A = np.random.standard_normal((100, 2))
A += np.array((-1, -1))

B = np.random.standard_normal((100, 2))
B += np.array((1, 1))

plt.scatter(B[:, 0], B[:, 1], c = 'r', s = 100.)
plt.scatter(A[:, 0], A[:, 1], c = 'w', s = 25.)

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

M = np.random.standard_normal((1000, 2))
R = np.sum(M ** 2, axis = 1)

plt.scatter(M[:, 0], M[:, 1], c = 'r', marker = 'o', s = 32. * R)
plt.show()

# %%
import numpy as np
import matplotlib.path as mpath
from matplotlib import pyplot as plt

shape_description = [
    (1., 2., mpath.Path.MOVETO),
    (1., 1., mpath.Path.LINETO),
    (2., 1., mpath.Path.LINETO),
    (2., -1., mpath.Path.LINETO),
    (1., -1., mpath.Path.LINETO),
    (1., -2., mpath.Path.LINETO),
    (-1., -2., mpath.Path.LINETO),
    (-1., -1., mpath.Path.LINETO),
    (-2., -1., mpath.Path.LINETO),
    (-2., 1., mpath.Path.LINETO),
    (-1., 1., mpath.Path.LINETO),
    (-2., 1., mpath.Path.LINETO),
    (-1., 2., mpath.Path.LINETO),
    (0., 0., mpath.Path.CLOSEPOLY),
]

u, v, codes = zip(*shape_description)
my_marker = mpath.Path(np.asarray((u, v)).T, codes)
data = np.random.rand(8, 8)
plt.scatter(data[:, 0], data[:, 1], c = 'r', marker = my_marker, s = 64)
                       
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-6, 6, 1024)
Y = np.sinc(X)

plt.plot(X, Y,
        linewidth = 3.,
        color = 'k',
        markersize = 9,
        markerfacecolor = '.75',
        markeredgecolor = 'k',
        marker = 'o',
        markevery = 32)

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
from cycler import cycler

default_cycler = (cycler(color=['r', 'g', 'b']))

mpl.rc('lines',linewidth = 2.)
mpl.rc('axes', facecolor = 'k', edgecolor = 'w')
mpl.rc('xtick', color = 'w')
mpl.rc('ytick', color = 'w')
mpl.rc('text', color = 'w')
mpl.rc('figure', facecolor = 'k', edgecolor = 'w')
mpl.rc('axes', prop_cycle = default_cycler)
                              
X = np.linspace(0, 7, 1024)
                              
plt.plot(X, np.sin(X))
plt.plot(X, np.cos(X))
                              
plt.show()

# %%
import matplotlib as mpl

mpl.get_configdir()
# Out:
# '/home/jovyan/.config/matplotlib'

# %% [markdown]
# ## Chapter 3 주석사용

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-4, 4, 1024)
Y = .25 *  (X + 4.) * (X + 1.) * (X - 2.)

plt.title('A Polynormal')
plt.plot(X, Y, c = 'r')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-4, 4, 1024)
Y = .25 *  (X + 4.) * (X + 1.) * (X - 2.)

plt.title('$f(x)=\\frac{1}{4}(x+4)(x+1)(x-2)$')
plt.plot(X, Y, c = 'r')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-4, 4, 1024)
Y = .25 *  (X + 4.) * (X + 1.) * (X - 2.)

plt.title('Power curve for airfoil KV873')
plt.xlabel('Air speed')
plt.ylabel('Total drag')

plt.plot(X, Y, c = 'r')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-4, 4, 1024)
Y = .25 *  (X + 4.) * (X + 1.) * (X - 2.)

plt.text(-0.5, -0.25, 'Brackmard minimum')

plt.plot(X, Y, c = 'r')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

box = {
    'facecolor': '.75',
    'edgecolor': 'k',
    'boxstyle': 'round'
}

X = np.linspace(-4, 4, 1024)
Y = .25 *  (X + 4.) * (X + 1.) * (X - 2.)

plt.text(-0.5, -0.20, 'Brackmard minimum', bbox = box)

plt.plot(X, Y, c = 'r')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-4, 4, 1024)
Y = .25 *  (X + 4.) * (X + 1.) * (X - 2.)

plt.annotate('Brackmard minimum', ha = 'center', va='bottom', xytext = (-1.5, 3.), xy = (0.75, -2.7), 
              arrowprops = {'facecolor': 'black', 'shrink': 0.05})

plt.plot(X, Y)

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(0, 6, 1024)
Y1 = np.sin(X)
Y2 = np.cos(X)

plt.xlabel('X')
plt.ylabel('Y')

plt.plot(X, Y1, c = 'r', lw = 3., label = 'sin(X)')
plt.plot(X, Y2, c = '.5', lw = 3., ls = '--', label = 'cox(X)')

plt.legend()
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-4, 4, 1024)
Y = .25 *  (X + 4.) * (X + 1.) * (X - 2.)

plt.plot(X, Y, c = 'k')
plt.grid(True, lw = 2, ls = '--', c = '.75')

plt.show()

# %%
from matplotlib import pyplot as plt

N = 16

for i in range(N):
    plt.gca().add_line(plt.Line2D((0, i), (N - i, 0), color='r'))

plt.grid(True)
plt.axis('scaled')

plt.show()

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt

shape = patches.Circle((0, 0), radius = 1., color = '.75')
plt.gca().add_patch(shape)

shape = patches.Rectangle((2.5, -.5), 2., 1.,  color = '.75')
plt.gca().add_patch(shape)


shape = patches.Ellipse((0, -2.), 2., 1.,  angle = 45., color = '.75')
plt.gca().add_patch(shape)

shape = patches.FancyBboxPatch((2.5, -2.5), 2., 1.,  boxstyle = 'sawtooth', color = '.75')
plt.gca().add_patch(shape)


plt.grid(True)
plt.axis('scaled')
plt.show()

# %%
import numpy as np
import matplotlib.patches as patches
import matplotlib.pyplot as plt

theta = np.linspace(0, 2*np.pi, 8)
points = np.vstack((np.cos(theta), np.sin(theta))).transpose()

plt.gca().add_patch(patches.Polygon(points, color = '.75'))

plt.grid(True)
plt.axis('scaled')

plt.show()

# %%
import numpy as np
import matplotlib.patches as patches
import matplotlib.pyplot as plt

theta = np.linspace(0, 2*np.pi, 8)
points = np.vstack((np.cos(theta), np.sin(theta))).transpose()

plt.gca().add_patch(plt.Circle((0,0), radius = 1., color = '.75'))
plt.gca().add_patch(plt.Polygon(points, closed = None, fill=None, lw = 3., ls = 'dashed', edgecolor = 'k'))

plt.grid(True)
plt.axis('scaled')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

X = np.linspace(-15, 15, 1024)
Y = np.sinc(X)

ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))

plt.plot(X, Y, c = 'r')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

X = np.linspace(-15, 15, 1024)
Y = np.sinc(X)

ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))

plt.grid(True, which='both')
plt.plot(X, Y, c = 'k')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

name_list = ('Omar', 'Serguey', 'Max', 'Zhou', 'Abidin')
value_list = np.random.randint(0, 99, size = len(name_list))
pos_list = np.arange(len(name_list))

ax = plt.axes()
ax.xaxis.set_major_locator(ticker.FixedLocator((pos_list)))
ax.xaxis.set_major_formatter(ticker.FixedFormatter((name_list)))

plt.bar(pos_list, value_list, color = '.75', align = 'center')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

name_list = ('Omar', 'Serguey', 'Max', 'Zhou', 'Abidin')
value_list = np.random.randint(0, 99, size = len(name_list))
pos_list = np.arange(len(name_list))

plt.bar(pos_list, value_list, color = '.75', align = 'center')
plt.xticks(pos_list,name_list)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def make_label(value, pos):
    return '%0.lf%%' % (100. * value)

ax = plt.axes()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(make_label))

X = np.linspace(0, 1, 256)

plt.plot(X, np.exp(-10 * X), c = 'r')
plt.plot(X, np.exp(-5 * X), c = 'r', ls = '--')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import datetime

start_date = datetime.datetime(1998, 1, 1)

def make_label(value, pos):
    time = start_date + datetime.timedelta(days = 365 * value)
    return time.strftime('%b %y')

ax = plt.axes()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(make_label))

X = np.linspace(0, 1, 256)

plt.plot(X, np.exp(-10 * X), c = 'r')
plt.plot(X, np.exp(-5 * X), c = 'r', ls = '--')


labels = ax.get_xticklabels()
plt.setp(labels, rotation = 30.)
plt.show()

# %% [markdown]
# ## Chapter 4 그림사용

# %%
import numpy as np
from matplotlib import pyplot as plt

T = np.linspace(-np.pi, np.pi, 1024)

grid_size = (4, 2)

plt.subplot2grid(grid_size, (0, 0), rowspan = 3, colspan = 1)
plt.plot(np.sin(2 * T), np.cos(0.5 * T), c = 'r')

plt.subplot2grid(grid_size, (0, 1), rowspan = 3, colspan = 1)
plt.plot(np.cos(3 * T), np.sin(T), c = 'g')

plt.subplot2grid(grid_size, (3, 0), rowspan = 1, colspan = 3)
plt.plot(np.cos(5 * T), np.sin(7 * T), c = 'b')

plt.tight_layout()
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

def get_radius(T, params):
    m,n_1,n_2,n_3 = params
    U = (m*T) / 4
    
    return (np.fabs(np.cos(U)) ** n_2 + np.fabs(np.sin(U)) ** n_3) ** (-1./n_1)

grid_size = (3, 4)
T = np.linspace(0, 2 * np.pi, 1024)

for i in range(grid_size[0]):
    for j in range(grid_size[1]):
        params = np.random.randint(1, 20, size=4)
        R = get_radius(T, params)
        
        axes = plt.subplot2grid(grid_size, (i, j), rowspan = 1, colspan = 1)
        axes.get_xaxis().set_visible(False)
        axes.get_yaxis().set_visible(False)
        
        plt.plot(R * np.cos(T), R * np.sin(T), c = 'r')
        plt.title("%d %d %d %d" % tuple(params), fontsize = 'small')

plt.tight_layout()
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

T = np.linspace(-np.pi, np.pi, 1024)

fig, (ax0, ax1) = plt.subplots(ncols = 2)
ax0.plot(np.sin(2 * T), np.cos(0.5 * T), c = 'r')
ax1.plot(np.cos(3 * T), np.sin(T), c = 'g')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

T = np.linspace(0, 2*np.pi, 1024)

plt.plot(2. * np.cos(T), np.sin(T), c = 'r', lw = 3.)

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-6, 6, 1024)
plt.ylim(-.5, 1.5)
plt.plot(X, np.sinc(X), c = 'r')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-6, 6, 1024)
Y1, Y2 = np.sinc(X), np.cos(X)

plt.figure(figsize = (10.24, 2.56))
plt.plot(X, Y1, c = 'k', lw = 3.)
plt.plot(X, Y2, c = 'r', lw = 3.)

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-6, 6, 1024)
Y = np.sinc(X)

X_detail = np.linspace(-3, 3, 1024)
Y_detail = np.sinc(X_detail)

plt.plot(X, Y, c = 'r')

sub_axes = plt.axes([.6,.6,.25,.25])
sub_axes.plot(X_detail, Y_detail, c = 'r')
plt.setp(sub_axes)

plt.show()
# Out:
#   adjustable: {'box', 'datalim'}
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array
#   alpha: scalar or None
#   anchor: (float, float) or {'C', 'SW', 'S', 'SE', 'E', 'NE', ...}
#   animated: bool
#   aspect: {'auto', 'equal'} or float
#   autoscale_on: bool
#   autoscalex_on: bool
#   autoscaley_on: bool
#   axes_locator: Callable[[Axes, Renderer], Bbox]
#   axisbelow: bool or 'line'
#   box_aspect: float or None
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   facecolor or fc: color
#   figure: `.Figure`
#   frame_on: bool
#   gid: str
#   in_layout: bool
#   label: object
#   navigate: bool
#   navigate_mode: unknown
#   path_effects: `.AbstractPathEffect`
#   picker: None or bool or float or callable
#   position: [left, bottom, width, height] or `~matplotlib.transforms.Bbox`
#   prop_cycle: unknown
#   rasterization_zorder: float or None
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   title: str
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xbound: unknown
#   xlabel: str
#   xlim: (bottom: float, top: float)
#   xmargin: float greater than -0.5
#   xscale: {"linear", "log", "symlog", "logit", ...} or `.ScaleBase`
#   xticklabels: unknown
#   xticks: unknown
#   ybound: unknown
#   ylabel: str
#   ylim: (bottom: float, top: float)
#   ymargin: float greater than -0.5
#   yscale: {"linear", "log", "symlog", "logit", ...} or `.ScaleBase`
#   yticklabels: unknown
#   yticks: unknown
#   zorder: float

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(1, 10, 1024)

plt.yscale('log')
plt.plot(X, X, c = 'b', lw = 2., label = r'$(x)=x$')
plt.plot(X, 10 ** X, c = 'r', ls = '--', lw = 2., label = r'$f(x)=e^x$')
plt.plot(X, np.log(X), c = 'g', lw = 2., label = r'$f(x)=\log(x)$')
         
plt.legend()
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-100, 100, 4096)

plt.xscale('symlog', linthresh=6.)
plt.plot(X, np.sinc(X), c = 'r')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

T = np.linspace(0, 2 * np.pi, 1024)

plt.axes(polar = True)
plt.plot(T, 1. + .25 * np.sin(16 * T), c = 'r')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import patches as patches

ax = plt.axes(polar = True)

theta = np.linspace(0, 2 * np.pi, 8, endpoint = False)
radius = .25 + .75 * np.random.random(size = len(theta))
points = np.vstack((theta, radius)).transpose()

plt.gca().add_patch(patches.Polygon(points, color = '.75'))
plt.show()

# %% [markdown]
# ## Chanper 5 파일출력처리

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-10, 10, 1024)
Y = np.sinc(X)

plt.plot(X, Y)
plt.savefig('sinc.png', dpi = 300)

# %%
import numpy as np
from matplotlib import pyplot as plt

name_list = ('Omar','Serquey','Max','Zhou','Abidin')
value_list = np.random.randint(99, size=len(name_list))
pos_list = np.arange(len(name_list))

plt.bar(pos_list, value_list, alpha=.75, color='r', align='center')
plt.xticks(pos_list, name_list)

plt.savefig('bar.png', transparent=True)

# %%
import numpy as np
from matplotlib import pyplot as plt

theta = np.linspace(0, 2 * np.pi, 8)
points = np.vstack((np.cos(theta), np.sin(theta))).transpose()

plt.figure(figsize=(4., 4.))
plt.gca().add_patch(plt.Polygon(points, color='r'))

plt.grid(True)
plt.axis('scaled')

plt.savefig('ploygon.png',dpi=128)

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.linspace(-10, 10, 1024)
Y = np.sinc(X)

plt.plot(X, Y)
plt.savefig('sinc.pdf')

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

data = np.random.randn(15, 1024)
pdf_pages = PdfPages('histograms.pdf')

plots_count = data.shape[0]
plots_per_page = 5
pages_count = int(np.ceil(plots_count/float(plots_per_page)))
grid_size = (plots_per_page, 1)

for i, samples in enumerate(data):
    if i % plots_per_page == 0:
        fig = plt.figure(figsize=(8.27, 11.69), dpi=100)
    
    plt.subplot2grid(grid_size, ( i % plots_per_page, 0))
    plt.hist(samples, 32, density=True, facecolor='.5', alpha=0.75)
    
    if (i + 1) % plots_per_page == 0 or (i + 1) == plots_count:
        plt.tight_layout()
        pdf_pages.savefig(fig)

pdf_pages.close()

# %% [markdown]
# ## Chapter 6 맵 처리

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm as cm

def iter_count(C, max_iter):
    X = C
    for n in range(max_iter):
        if abs(X) > 2.:
            return n
        X = X ** 2 + C
    
    return max_iter

N = 512
max_iter = 64
xmin, xmax, ymin, ymax = -2.2, .8, -1.5, 1.5

X = np.linspace(xmin, xmax, N)
Y = np.linspace(ymin, ymax, N)
Z = np.empty((N, N))

for i, y in enumerate(Y):
    for j, x in enumerate(X):
        Z[i, j] = iter_count(complex(x, y), max_iter)

plt.imshow(Z, cmap = cm.binary, interpolation='bicubic', extent=(xmin, xmax, ymin, ymax))
cb = plt.colorbar(orientation='horizontal', shrink=.75)
cb.set_label('iteration count')

plt.show()

# %%
import numpy as np
from numpy.random import uniform, seed
from matplotlib import pyplot as plt
from matplotlib.mlab import griddata
import matplotlib.cm as cm

def iter_count(C, max_iter):
    X = C
    for n in range(max_iter):
        if abs(X) > 2.:
            return n
        X = X ** 2 + C
    
    return max_iter

max_iter = 64
xmin, xmax, ymin, ymax = -2.2, .8, -1.5, 1.5

sample_count  = 2 ** 12
A = uniform(xmin, xmax, sample_count)
B = uniform(ymin, ymax, sample_count)
C = [iter_count(complex(a, b), max_iter) for a, b in zip(A, B)]

N = 523

X = np.linspace(xmin, xmax, N)
Y = np.linspace(ymin, ymax, N)
Z = griddata(A, B, C, X, Y, iterp='linear')

plt.scatter(A, B, color = (0., 0., 0., .5), s = .5)

plt.imshow(Z, cmap = cm.binary, interpolation='bicubic', extent=(xmin, xmax, ymin, ymax))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [121], in <cell line: 4>()
#       2 from numpy.random import uniform, seed
#       3 from matplotlib import pyplot as plt
# ----> 4 from matplotlib.mlab import grid
#       5 import matplotlib.cm as cm
#       7 def iter_count(C, max_iter):
#
# ImportError: cannot import name 'grid' from 'matplotlib.mlab' (/opt/conda/lib/python3.9/site-packages/matplotlib/mlab.py)

# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm

n = 256
x = np.linspace(-3., 3., n)
y = np.linspace(-3., 3., n)
X, Y = np.meshgrid(x, y)

Z = X * np.sinc(X ** 2 + Y ** 2)

plt.pcolormesh(X, Y, Z, cmap = cm.gray)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm as cm

def iter_count(C, max_iter):
    X = C
    for n in range(max_iter):
        if abs(X) > 2.:
            return n
        X = X ** 2 + C
    
    return max_iter

N = 512
max_iter = 64
xmin, xmax, ymin, ymax = -0.32, -0.22, 0.8, 0.9

X = np.linspace(xmin, xmax, N)
Y = np.linspace(ymin, ymax, N)
Z = np.empty((N, N))

for i, y in enumerate(Y):
    for j, x in enumerate(X):
        Z[i, j] = iter_count(complex(x, y), max_iter)

plt.imshow(Z, cmap = cm.binary, interpolation='bicubic', origin='lower', extent=(xmin, xmax, ymin, ymax))
levels = [8, 12, 16, 20]

ct = plt.contour(X, Y, Z, levels, cmap = cm.gray)
plt.clabel(ct, fmt='%d')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm as cm

def iter_count(C, max_iter):
    X = C
    for n in range(max_iter):
        if abs(X) > 2.:
            return n
        X = X ** 2 + C
    
    return max_iter

N = 512
max_iter = 64
xmin, xmax, ymin, ymax = -0.32, -0.22, 0.8, 0.9

X = np.linspace(xmin, xmax, N)
Y = np.linspace(ymin, ymax, N)
Z = np.empty((N, N))

for i, y in enumerate(Y):
    for j, x in enumerate(X):
        Z[i, j] = iter_count(complex(x, y), max_iter)

plt.imshow(Z, cmap = cm.binary, interpolation='bicubic', origin='lower', extent=(xmin, xmax, ymin, ymax))
levels = [8, 12, 16, 20]

ct = plt.contourf(X, Y, Z, levels, cmap = cm.gray, antialiased = True)
plt.clabel(ct, fmt='%d')

plt.show()

# %%
import numpy as np
import sympy
from sympy.abc import x, y
from matplotlib import pyplot as plt
import matplotlib.patches as patches

def cylinder_stream_function(U=1, R=1):
    r = sympy.sqrt(x ** 2 + y ** 2)
    theta = sympy.atan2(y, x)
    return U * (r - R ** 2 / r) * sympy.sin(theta)

def velocity_field(psi):
    u = sympy.lambdify((x, y), psi.diff(y), 'numpy')
    v = sympy.lambdify((x, y), -psi.diff(x), 'numpy')
    return u, v

U_func, V_func = velocity_field(cylinder_stream_function())
xmin, xmax, ymin, ymax = -2.5, 2.5, -2.5, 2.5

Y, X = np.ogrid[ymin:ymax:16j, xmin:xmax:16j]
U, V = U_func(X, Y), V_func(X, Y)

M = (X ** 2 + Y ** 2) < 1.
U = np.ma.masked_array(U, mask = M)
V = np.ma.masked_array(V, mask = M)

shape = patches.Circle((0,0), radius = 1., lw = 2., fc = 'w', ec = 'k', zorder = 0)
plt.gca().add_patch(shape)

plt.quiver(X, Y, U, V, zorder = 1)
plt.axes().set_aspect('equal')

plt.show()

# %% [markdown]
# ## Chapter 7 3D 그림사용

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

a, b, c = 10., 28., 8./3.
def lorenz_map(X, dt = 1e-2):
    X_dt = np.array([a * (X[1] - X[0]), X[0] * (b - X[2]) - X[1], X[0] * X[1] - c * X[2]])
    return X + dt * X_dt

points = np.zeros((2000, 3))
X = np.array([.1, .0, .0])

for i in range(points.shape[0]):
    points[i], X = X, lorenz_map(X)
    
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
ax.set_title('Lorenz Attractor a=%0.2f b=%0.2f c=%0.2f' % (a, b, c))

ax.scatter(points[:, 0], points[:, 1], points[:, 2], zdir = 'y', c = 'r')
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

a, b, c = 10., 28., 8./3.
def lorenz_map(X, dt = 1e-2):
    X_dt = np.array([a * (X[1] - X[0]), X[0] * (b - X[2]) - X[1], X[0] * X[1] - c * X[2]])
    return X + dt * X_dt

points = np.zeros((2000, 3))
X = np.array([.1, .0, .0])

for i in range(points.shape[0]):
    points[i], X = X, lorenz_map(X)
    
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.plot(points[:, 0], points[:, 1], points[:, 2], c = 'r')
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm

x = np.linspace(-3, 3, 256)
y = np.linspace(-3, 3, 256)
X, Y = np.meshgrid(x, y)
Z = np.sinc(np.sqrt(X**2 + y**2))

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_surface(X, Y, Z, cmap=cm.gray, antialiased = False)
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm

x = np.linspace(-3, 3, 256)
y = np.linspace(-3, 3, 256)
X, Y = np.meshgrid(x, y)
Z = np.sinc(np.sqrt(X**2 + y**2))

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_wireframe(X, Y, Z, cstride=8, rstride=8, color='k')
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

angle = np.linspace(0, 2 * np.pi, 32)
theta, phi = np.meshgrid(angle, angle)
r, R = .25, 1.

X = (R + r * np.cos(phi)) * np.cos(theta)
Y = (R + r * np.cos(phi)) * np.sin(theta)
Z = r * np.sin(phi)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.set_xlim3d(-1, 1)
ax.set_ylim3d(-1, 1)
ax.set_zlim3d(-1, 1)

ax.plot_surface(X, Y, Z, color='w', rstride = 1, cstride = 1)
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

x = np.linspace(-3, 3, 256)
y = np.linspace(-3, 3, 256)
X, Y = np.meshgrid(x, y)
Z = np.exp(-(X**2 + y**2))
u = np.exp(-(X**2))

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.set_zlim3d(0, 3)
ax.plot(x, u, zs = 3, zdir='y', lw = 2., color = '.75')
ax.plot(x, u, zs = -3, zdir='x', lw = 2., color = 'k')
ax.plot_surface(X, Y, Z, color='w')

plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.colors as col

alpha = 1. / np.linspace(1, 8, 5)
t = np.linspace(0, 5, 16)
T, A = np.meshgrid(t, alpha)
data = np.exp(-T*A)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
cmap = cm.ScalarMappable(col.Normalize(0, len(alpha)), cm.gray)

for i, row in enumerate(data):
    ax.bar(4 * t, row, zs = 1, zdir = 'y', alpha = 0.8, color=cmap.to_rgba(i))
    
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

alpha = 1. / np.linspace(1, 8, 5)
t = np.linspace(0, 5, 16)
T, A = np.meshgrid(t, alpha)
data = np.exp(-T*(1./A))

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')

Xi = T.flatten()
Yi = A.flatten()
Zi = np.zeros(data.size)

dx = .25 * np.ones(data.size)
dy = .25 * np.ones(data.size)
dz = data.flatten()

ax.set_xlabel('T')
ax.set_ylabel('Alpha')
ax.bar3d(Xi, Yi, Zi, dx, dy, dz, color='w')

plt.show()

# %% [markdown]
# ## chapter 8 사용자 인터페이스

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.widgets import Slider

def supershape_radius(phi, a, b, m, n1, n2, n3):
    theta = .25 * m * phi
    cos = np.fabs(np.cos(theta) / a) ** n2
    sin = np.fabs(np.sin(theta) / b) ** n3
    r = (cos + sin) ** (-1. / n1)
    r /= np.max(r)
    
    return r

phi = np.linspace(0, 2*np.pi, 1024)
m_init = 3
n1_init = 2
n2_init = 18
n3_init = 18

fig = plt.figure()
ax = fig.add_subplot(111, polar = True)

ax_m = plt.axes([0.05, 0.05, 0.25, 0.025])
ax_n1 = plt.axes([0.05, 0.10, 0.25, 0.025])
ax_n2 = plt.axes([0.07, 0.05, 0.25, 0.025])                
ax_n3 = plt.axes([0.07, 0.10, 0.25, 0.025])                

slider_m = Slider(ax_m, 'm', 1, 20, valinit = m_init)
slider_n1 = Slider(ax_n1, 'n1', .1, 10, valinit = n1_init)
slider_n2 = Slider(ax_n2, 'n2', .1, 20, valinit = n2_init)
slider_n3 = Slider(ax_n3, 'n3', .1, 20, valinit = n3_init)

r = supershape_radius(phi, 1, 1, m_init, n1_init, n2_init, n3_init)
lines, = ax.plot(phi, r, lw = 3.)

def update(val):
    r = supershape_radius(phi, 1, 1, np.floor(slider_m.val), slider_n1.val, slider_n2.val, slider_n3.val)
    line.set_ydata(r)
    fig.canvas.draw_idle()
    
slider_n1.on_changed(update)
slider_n2.on_changed(update)
slider_n3.on_changed(update)
slider_m.on_changed(update)

plt.show()
